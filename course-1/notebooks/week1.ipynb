# %% [markdown]
# # Week 1: Introduction to Deep Learning
# ----
# **Learning Objectives:**
# - Discuss the major trends driving the rise of deep learning
# - Explain how deep learning is applied to supervised learning
# - List the major categories of models (CNNs, RNNs, etc.), and when they should be applied
# - Assess appropriate use cases for deep learning

# %% [markdown]
# Here is a high-level example of a neural network system for predicting housing price ($\hat y$) based on house features ($
# \mathbf{X}$):
# z
# ![High level NN example](images/nn_hl_example.png)
#
# In the above example, first layer is called **input layer** and middle layer is called **hidden layer**.
#
# There are different types of neural networks that are applied to different problems. Here is three common ones:
#
# ![NN common types](images/nn_types.png)
#
#
# In supervised learning, generally, there are two types of data: (1) structured data (e.g. databases), (2) Unstructured data (e.g. audio, image, text).
#
#
# **Data scale drives deep learning progress and performance:**
#
# ![performamce scales with data](images/scale_dl_progress.png)
#
#
# Other than large sacle of data, better computation capability and faster algorithms have contributed to deep learning progress.
